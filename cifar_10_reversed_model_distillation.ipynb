# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
training_losses_without_distilation = []
class TeacherModel(nn.Module):
    def __init__(self):
        super(TeacherModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 10)
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = x.view(-1, 16 * 16 * 16)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)

def train_teacher(model, optimizer, criterion, epochs=15):
    model.train()
    training_losses = []
    for epoch in range(epochs):
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            if i % 100 == 99:  # Print every 100 mini-batches
                print(f'Epoch [{epoch+1}/{epochs}], Batch [{i+1}/{len(train_loader)}], Loss: {running_loss / 100:.4f}')
                training_losses.append(running_loss / 100)
                running_loss = 0.0
    # Plotting training loss over time
    plt.plot(training_losses)
    plt.xlabel('Batch (100 intervals)')
    plt.ylabel('Loss')
    plt.title('Training Loss during training without distillation')
    plt.show()
    training_losses_under_two = [x for x in training_losses if x <= 2]
    plt.plot(training_losses_under_two)
    plt.xlabel('Batch (100 intervals)')
    plt.ylabel('Loss')
    plt.title('Training Loss during training without distillation (without losses above 2)')
    plt.show()
    return training_losses;

def test_model(model):
    model.eval()
    correct = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            correct += predicted.eq(targets).sum().item()
    print(f'Accuracy: {100. * correct / len(test_loader.dataset)}%')

teacher_model = TeacherModel().to(device)
teacher_optimizer = optim.Adam(teacher_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

print("Training Teacher Model...")
train_teacher(teacher_model, teacher_optimizer, criterion)
print("Teacher model testing:")
test_model(teacher_model)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.1MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Training Teacher Model...
# Epoch [1/15], Batch [100/782], Loss: 2.0095
# Epoch [1/15], Batch [200/782], Loss: 1.7660
# Epoch [1/15], Batch [300/782], Loss: 1.6619
# Epoch [1/15], Batch [400/782], Loss: 1.5581
# Epoch [1/15], Batch [500/782], Loss: 1.5386
# Epoch [1/15], Batch [600/782], Loss: 1.5054
# Epoch [1/15], Batch [700/782], Loss: 1.4673
# Epoch [2/15], Batch [100/782], Loss: 1.4161
# Epoch [2/15], Batch [200/782], Loss: 1.4241
# Epoch [2/15], Batch [300/782], Loss: 1.4255
# Epoch [2/15], Batch [400/782], Loss: 1.3755
# Epoch [2/15], Batch [500/782], Loss: 1.4067
# Epoch [2/15], Batch [600/782], Loss: 1.3771
# Epoch [2/15], Batch [700/782], Loss: 1.3613
# Epoch [3/15], Batch [100/782], Loss: 1.3230
# Epoch [3/15], Batch [200/782], Loss: 1.3106
# Epoch [3/15], Batch [300/782], Loss: 1.2983
# Epoch [3/15], Batch [400/782], Loss: 1.3297
# Epoch [3/15], Batch [500/782], Loss: 1.3219
# Epoch [3/15], Batch [600/782], Loss: 1.3109
# Epoch [3/15], Batch [700/782], Loss: 1.3080
# Epoch [4/15], Batch [100/782], Loss: 1.2495
# Epoch [4/15], Batch [200/782], Loss: 1.2472
# Epoch [4/15], Batch [300/782], Loss: 1.2587
# Epoch [4/15], Batch [400/782], Loss: 1.2401
# Epoch [4/15], Batch [500/782], Loss: 1.2626
# Epoch [4/15], Batch [600/782], Loss: 1.2749
# Epoch [4/15], Batch [700/782], Loss: 1.2375
# Epoch [5/15], Batch [100/782], Loss: 1.2110
# Epoch [5/15], Batch [200/782], Loss: 1.2019
# Epoch [5/15], Batch [300/782], Loss: 1.2202
# Epoch [5/15], Batch [400/782], Loss: 1.2088
# Epoch [5/15], Batch [500/782], Loss: 1.2346
# Epoch [5/15], Batch [600/782], Loss: 1.2291
# Epoch [5/15], Batch [700/782], Loss: 1.2024
# Epoch [6/15], Batch [100/782], Loss: 1.1965
# Epoch [6/15], Batch [200/782], Loss: 1.1863
# Epoch [6/15], Batch [300/782], Loss: 1.1882
# Epoch [6/15], Batch [400/782], Loss: 1.1898
# Epoch [6/15], Batch [500/782], Loss: 1.1912
# Epoch [6/15], Batch [600/782], Loss: 1.1750
# Epoch [6/15], Batch [700/782], Loss: 1.1816
# Epoch [7/15], Batch [100/782], Loss: 1.1406
# Epoch [7/15], Batch [200/782], Loss: 1.1644
# Epoch [7/15], Batch [300/782], Loss: 1.1394
# Epoch [7/15], Batch [400/782], Loss: 1.1474
# Epoch [7/15], Batch [500/782], Loss: 1.1828
# Epoch [7/15], Batch [600/782], Loss: 1.1634
# Epoch [7/15], Batch [700/782], Loss: 1.1592
# Epoch [8/15], Batch [100/782], Loss: 1.1111
# Epoch [8/15], Batch [200/782], Loss: 1.1140
# Epoch [8/15], Batch [300/782], Loss: 1.1248
# Epoch [8/15], Batch [400/782], Loss: 1.1521
# Epoch [8/15], Batch [500/782], Loss: 1.1167
# Epoch [8/15], Batch [600/782], Loss: 1.1249
# Epoch [8/15], Batch [700/782], Loss: 1.1489
# Epoch [9/15], Batch [100/782], Loss: 1.0951
# Epoch [9/15], Batch [200/782], Loss: 1.1106
# Epoch [9/15], Batch [300/782], Loss: 1.1202
# Epoch [9/15], Batch [400/782], Loss: 1.1145
# Epoch [9/15], Batch [500/782], Loss: 1.1154
# Epoch [9/15], Batch [600/782], Loss: 1.1130
# Epoch [9/15], Batch [700/782], Loss: 1.0953
# Epoch [10/15], Batch [100/782], Loss: 1.0669
# Epoch [10/15], Batch [200/782], Loss: 1.0584
# Epoch [10/15], Batch [300/782], Loss: 1.0820
# Epoch [10/15], Batch [400/782], Loss: 1.0721
# Epoch [10/15], Batch [500/782], Loss: 1.0968
# Epoch [10/15], Batch [600/782], Loss: 1.0922
# Epoch [10/15], Batch [700/782], Loss: 1.1187
# Epoch [11/15], Batch [100/782], Loss: 1.0645
# Epoch [11/15], Batch [200/782], Loss: 1.0462
# Epoch [11/15], Batch [300/782], Loss: 1.0581
# Epoch [11/15], Batch [400/782], Loss: 1.0536
# Epoch [11/15], Batch [500/782], Loss: 1.1010
# Epoch [11/15], Batch [600/782], Loss: 1.0769
# Epoch [11/15], Batch [700/782], Loss: 1.0809
# Epoch [12/15], Batch [100/782], Loss: 1.0249
# Epoch [12/15], Batch [200/782], Loss: 1.0322
# Epoch [12/15], Batch [300/782], Loss: 1.0473
# Epoch [12/15], Batch [400/782], Loss: 1.0594
# Epoch [12/15], Batch [500/782], Loss: 1.0461
# Epoch [12/15], Batch [600/782], Loss: 1.0744
# Epoch [12/15], Batch [700/782], Loss: 1.0726
# Epoch [13/15], Batch [100/782], Loss: 1.0133
# Epoch [13/15], Batch [200/782], Loss: 1.0335
# Epoch [13/15], Batch [300/782], Loss: 1.0388
# Epoch [13/15], Batch [400/782], Loss: 1.0016
# Epoch [13/15], Batch [500/782], Loss: 1.0519
# Epoch [13/15], Batch [600/782], Loss: 1.0555
# Epoch [13/15], Batch [700/782], Loss: 1.0312
# Epoch [14/15], Batch [100/782], Loss: 1.0171
# Epoch [14/15], Batch [200/782], Loss: 1.0193
# Epoch [14/15], Batch [300/782], Loss: 1.0170
# Epoch [14/15], Batch [400/782], Loss: 1.0215
# Epoch [14/15], Batch [500/782], Loss: 1.0291
# Epoch [14/15], Batch [600/782], Loss: 1.0251
# Epoch [14/15], Batch [700/782], Loss: 1.0001
# Epoch [15/15], Batch [100/782], Loss: 0.9746
# Epoch [15/15], Batch [200/782], Loss: 1.0063
# Epoch [15/15], Batch [300/782], Loss: 1.0095
# Epoch [15/15], Batch [400/782], Loss: 0.9913
# Epoch [15/15], Batch [500/782], Loss: 1.0018
# Epoch [15/15], Batch [600/782], Loss: 0.9978
# Epoch [15/15], Batch [700/782], Loss: 1.0270
# Teacher model testing:
# Accuracy: 62.16%

# %%
class StudentModel(nn.Module):
    def __init__(self):
        super(StudentModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(512 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = self.pool(F.relu(self.conv4(x)))
        x = F.relu(self.conv5(x))
        x = x.view(-1, 512 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        return self.fc3(x)

def train_student(student_model, teacher_model, optimizer, temperature=7.0, alpha=0.6, epochs=15):
    student_model.train()
    teacher_model.eval()
    training_losses = []

    for epoch in range(epochs):
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()

            # Teacher outputs with temperature
            with torch.no_grad():
                teacher_outputs = teacher_model(inputs) / temperature

            # Student outputs
            student_outputs = student_model(inputs) / temperature

            # Hard and soft losses
            loss_hard = criterion(student_outputs, targets)
            loss_soft = F.kl_div(F.log_softmax(student_outputs, dim=1),
                                 F.softmax(teacher_outputs, dim=1),
                                 reduction='batchmean')

            # Combined loss
            loss = alpha * loss_hard + (1 - alpha) * loss_soft * (temperature ** 2)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            if i % 100 == 99:  # Print every 100 mini-batches
                print(f'Epoch [{epoch+1}/{epochs}], Batch [{i+1}/{len(train_loader)}], Loss: {running_loss / 100:.4f}')
                training_losses.append(running_loss / 100)
                running_loss = 0.0

    plt.plot(training_losses)
    plt.xlabel('Batch (100 intervals)')
    plt.ylabel('Loss')
    plt.title('Training Loss during Distillation')
    plt.show()
    training_losses_under_two = [x for x in training_losses if x <= 2]
    plt.plot(training_losses_under_two)
    plt.xlabel('Batch (100 intervals)')
    plt.ylabel('Loss')
    plt.title('Training Loss during Distillation (without losses above 2)')
    plt.show()
    return training_losses;

student_model = StudentModel().to(device)
student_optimizer = optim.Adam(student_model.parameters(), lr=0.001)
print("Training Student Model with Distillation...")
training_losses_with_distill = train_student(student_model, teacher_model, student_optimizer)

print("Student model testing with distillation:")
test_model(student_model)

student_model_no_distill = StudentModel().to(device)
student_optimizer_no_distill = optim.Adam(student_model_no_distill.parameters(), lr=0.001)
print("Training Student Model without Distillation...")
training_losses_without_distill = train_teacher(student_model_no_distill, student_optimizer_no_distill, criterion)

print("Student model testing without distillation:")
test_model(student_model_no_distill)

plt.plot(training_losses_with_distill, label='S distilací')
plt.plot(training_losses_without_distill, label='Bez distilace')
plt.xlabel('Batch (100 intervalů)')
plt.ylabel('Ztráta (Loss)')
plt.title('Ztráty během trénování: s distilací a bez distilace')
plt.legend()
plt.show()
# Out:
# Training Student Model with Distillation...
# Epoch [1/15], Batch [100/782], Loss: 2.6614
# Epoch [1/15], Batch [200/782], Loss: 1.9210
# Epoch [1/15], Batch [300/782], Loss: 1.6803
# Epoch [1/15], Batch [400/782], Loss: 1.5978
# Epoch [1/15], Batch [500/782], Loss: 1.5291
# Epoch [1/15], Batch [600/782], Loss: 1.4708
# Epoch [1/15], Batch [700/782], Loss: 1.4061
# Epoch [2/15], Batch [100/782], Loss: 1.3514
# Epoch [2/15], Batch [200/782], Loss: 1.3293
# Epoch [2/15], Batch [300/782], Loss: 1.3166
# Epoch [2/15], Batch [400/782], Loss: 1.3146
# Epoch [2/15], Batch [500/782], Loss: 1.2973
# Epoch [2/15], Batch [600/782], Loss: 1.2831
# Epoch [2/15], Batch [700/782], Loss: 1.2723
# Epoch [3/15], Batch [100/782], Loss: 1.2421
# Epoch [3/15], Batch [200/782], Loss: 1.2508
# Epoch [3/15], Batch [300/782], Loss: 1.2362
# Epoch [3/15], Batch [400/782], Loss: 1.2535
# Epoch [3/15], Batch [500/782], Loss: 1.2396
# Epoch [3/15], Batch [600/782], Loss: 1.2488
# Epoch [3/15], Batch [700/782], Loss: 1.2443
# Epoch [4/15], Batch [100/782], Loss: 1.2053
# Epoch [4/15], Batch [200/782], Loss: 1.2116
# Epoch [4/15], Batch [300/782], Loss: 1.2042
# Epoch [4/15], Batch [400/782], Loss: 1.2044
# Epoch [4/15], Batch [500/782], Loss: 1.2082
# Epoch [4/15], Batch [600/782], Loss: 1.2008
# Epoch [4/15], Batch [700/782], Loss: 1.2054
# Epoch [5/15], Batch [100/782], Loss: 1.1820
# Epoch [5/15], Batch [200/782], Loss: 1.1801
# Epoch [5/15], Batch [300/782], Loss: 1.1801
# Epoch [5/15], Batch [400/782], Loss: 1.1826
# Epoch [5/15], Batch [500/782], Loss: 1.1813
# Epoch [5/15], Batch [600/782], Loss: 1.1822
# Epoch [5/15], Batch [700/782], Loss: 1.1837
# Epoch [6/15], Batch [100/782], Loss: 1.1553
# Epoch [6/15], Batch [200/782], Loss: 1.1564
# Epoch [6/15], Batch [300/782], Loss: 1.1637
# Epoch [6/15], Batch [400/782], Loss: 1.1663
# Epoch [6/15], Batch [500/782], Loss: 1.1647
# Epoch [6/15], Batch [600/782], Loss: 1.1621
# Epoch [6/15], Batch [700/782], Loss: 1.1707
# Epoch [7/15], Batch [100/782], Loss: 1.1499
# Epoch [7/15], Batch [200/782], Loss: 1.1423
# Epoch [7/15], Batch [300/782], Loss: 1.1445
# Epoch [7/15], Batch [400/782], Loss: 1.1430
# Epoch [7/15], Batch [500/782], Loss: 1.1443
# Epoch [7/15], Batch [600/782], Loss: 1.1496
# Epoch [7/15], Batch [700/782], Loss: 1.1510
# Epoch [8/15], Batch [100/782], Loss: 1.1308
# Epoch [8/15], Batch [200/782], Loss: 1.1341
# Epoch [8/15], Batch [300/782], Loss: 1.1321
# Epoch [8/15], Batch [400/782], Loss: 1.1377
# Epoch [8/15], Batch [500/782], Loss: 1.1334
# Epoch [8/15], Batch [600/782], Loss: 1.1377
# Epoch [8/15], Batch [700/782], Loss: 1.1407
# Epoch [9/15], Batch [100/782], Loss: 1.1249
# Epoch [9/15], Batch [200/782], Loss: 1.1193
# Epoch [9/15], Batch [300/782], Loss: 1.1254
# Epoch [9/15], Batch [400/782], Loss: 1.1340
# Epoch [9/15], Batch [500/782], Loss: 1.1227
# Epoch [9/15], Batch [600/782], Loss: 1.1288
# Epoch [9/15], Batch [700/782], Loss: 1.1298
# Epoch [10/15], Batch [100/782], Loss: 1.1158
# Epoch [10/15], Batch [200/782], Loss: 1.1193
# Epoch [10/15], Batch [300/782], Loss: 1.1231
# Epoch [10/15], Batch [400/782], Loss: 1.1164
# Epoch [10/15], Batch [500/782], Loss: 1.1182
# Epoch [10/15], Batch [600/782], Loss: 1.1203
# Epoch [10/15], Batch [700/782], Loss: 1.1251
# Epoch [11/15], Batch [100/782], Loss: 1.1159
# Epoch [11/15], Batch [200/782], Loss: 1.1079
# Epoch [11/15], Batch [300/782], Loss: 1.1077
# Epoch [11/15], Batch [400/782], Loss: 1.1100
# Epoch [11/15], Batch [500/782], Loss: 1.1140
# Epoch [11/15], Batch [600/782], Loss: 1.1185
# Epoch [11/15], Batch [700/782], Loss: 1.1141
# Epoch [12/15], Batch [100/782], Loss: 1.1122
# Epoch [12/15], Batch [200/782], Loss: 1.1070
# Epoch [12/15], Batch [300/782], Loss: 1.1064
# Epoch [12/15], Batch [400/782], Loss: 1.1093
# Epoch [12/15], Batch [500/782], Loss: 1.1051
# Epoch [12/15], Batch [600/782], Loss: 1.1014
# Epoch [12/15], Batch [700/782], Loss: 1.1101
# Epoch [13/15], Batch [100/782], Loss: 1.0995
# Epoch [13/15], Batch [200/782], Loss: 1.1026
# Epoch [13/15], Batch [300/782], Loss: 1.1034
# Epoch [13/15], Batch [400/782], Loss: 1.1027
# Epoch [13/15], Batch [500/782], Loss: 1.1024
# Epoch [13/15], Batch [600/782], Loss: 1.1028
# Epoch [13/15], Batch [700/782], Loss: 1.1021
# Epoch [14/15], Batch [100/782], Loss: 1.0961
# Epoch [14/15], Batch [200/782], Loss: 1.0929
# Epoch [14/15], Batch [300/782], Loss: 1.0975
# Epoch [14/15], Batch [400/782], Loss: 1.0995
# Epoch [14/15], Batch [500/782], Loss: 1.1033
# Epoch [14/15], Batch [600/782], Loss: 1.0930
# Epoch [14/15], Batch [700/782], Loss: 1.1010
# Epoch [15/15], Batch [100/782], Loss: 1.0975
# Epoch [15/15], Batch [200/782], Loss: 1.0884
# Epoch [15/15], Batch [300/782], Loss: 1.0916
# Epoch [15/15], Batch [400/782], Loss: 1.0945
# Epoch [15/15], Batch [500/782], Loss: 1.0953
# Epoch [15/15], Batch [600/782], Loss: 1.0993
# Epoch [15/15], Batch [700/782], Loss: 1.0999
# Student model testing with distillation:
# Accuracy: 71.55%
# Training Student Model without Distillation...
# Epoch [1/15], Batch [100/782], Loss: 2.1037
# Epoch [1/15], Batch [200/782], Loss: 1.7918
# Epoch [1/15], Batch [300/782], Loss: 1.5657
# Epoch [1/15], Batch [400/782], Loss: 1.4748
# Epoch [1/15], Batch [500/782], Loss: 1.3477
# Epoch [1/15], Batch [600/782], Loss: 1.2887
# Epoch [1/15], Batch [700/782], Loss: 1.1978
# Epoch [2/15], Batch [100/782], Loss: 1.0648
# Epoch [2/15], Batch [200/782], Loss: 0.9970
# Epoch [2/15], Batch [300/782], Loss: 0.9822
# Epoch [2/15], Batch [400/782], Loss: 0.9311
# Epoch [2/15], Batch [500/782], Loss: 0.8945
# Epoch [2/15], Batch [600/782], Loss: 0.8777
# Epoch [2/15], Batch [700/782], Loss: 0.8797
# Epoch [3/15], Batch [100/782], Loss: 0.7111
# Epoch [3/15], Batch [200/782], Loss: 0.6956
# Epoch [3/15], Batch [300/782], Loss: 0.7005
# Epoch [3/15], Batch [400/782], Loss: 0.6883
# Epoch [3/15], Batch [500/782], Loss: 0.6802
# Epoch [3/15], Batch [600/782], Loss: 0.7118
# Epoch [3/15], Batch [700/782], Loss: 0.6668
# Epoch [4/15], Batch [100/782], Loss: 0.4991
# Epoch [4/15], Batch [200/782], Loss: 0.5344
# Epoch [4/15], Batch [300/782], Loss: 0.5286
# Epoch [4/15], Batch [400/782], Loss: 0.5418
# Epoch [4/15], Batch [500/782], Loss: 0.5459
# Epoch [4/15], Batch [600/782], Loss: 0.5530
# Epoch [4/15], Batch [700/782], Loss: 0.5332
# Epoch [5/15], Batch [100/782], Loss: 0.3712
# Epoch [5/15], Batch [200/782], Loss: 0.3648
# Epoch [5/15], Batch [300/782], Loss: 0.4032
# Epoch [5/15], Batch [400/782], Loss: 0.4035
# Epoch [5/15], Batch [500/782], Loss: 0.4170
# Epoch [5/15], Batch [600/782], Loss: 0.3947
# Epoch [5/15], Batch [700/782], Loss: 0.4168
# Epoch [6/15], Batch [100/782], Loss: 0.2344
# Epoch [6/15], Batch [200/782], Loss: 0.2487
# Epoch [6/15], Batch [300/782], Loss: 0.2753
# Epoch [6/15], Batch [400/782], Loss: 0.2957
# Epoch [6/15], Batch [500/782], Loss: 0.2903
# Epoch [6/15], Batch [600/782], Loss: 0.3131
# Epoch [6/15], Batch [700/782], Loss: 0.2986
# Epoch [7/15], Batch [100/782], Loss: 0.1621
# Epoch [7/15], Batch [200/782], Loss: 0.1773
# Epoch [7/15], Batch [300/782], Loss: 0.1963
# Epoch [7/15], Batch [400/782], Loss: 0.2101
# Epoch [7/15], Batch [500/782], Loss: 0.2337
# Epoch [7/15], Batch [600/782], Loss: 0.1972
# Epoch [7/15], Batch [700/782], Loss: 0.2106
# Epoch [8/15], Batch [100/782], Loss: 0.1321
# Epoch [8/15], Batch [200/782], Loss: 0.1173
# Epoch [8/15], Batch [300/782], Loss: 0.1421
# Epoch [8/15], Batch [400/782], Loss: 0.1725
# Epoch [8/15], Batch [500/782], Loss: 0.1763
# Epoch [8/15], Batch [600/782], Loss: 0.1611
# Epoch [8/15], Batch [700/782], Loss: 0.1813
# Epoch [9/15], Batch [100/782], Loss: 0.0883
# Epoch [9/15], Batch [200/782], Loss: 0.1218
# Epoch [9/15], Batch [300/782], Loss: 0.1257
# Epoch [9/15], Batch [400/782], Loss: 0.1151
# Epoch [9/15], Batch [500/782], Loss: 0.1395
# Epoch [9/15], Batch [600/782], Loss: 0.1262
# Epoch [9/15], Batch [700/782], Loss: 0.1467
# Epoch [10/15], Batch [100/782], Loss: 0.0861
# Epoch [10/15], Batch [200/782], Loss: 0.1215
# Epoch [10/15], Batch [300/782], Loss: 0.1200
# Epoch [10/15], Batch [400/782], Loss: 0.1099
# Epoch [10/15], Batch [500/782], Loss: 0.1100
# Epoch [10/15], Batch [600/782], Loss: 0.0955
# Epoch [10/15], Batch [700/782], Loss: 0.1178
# Epoch [11/15], Batch [100/782], Loss: 0.0885
# Epoch [11/15], Batch [200/782], Loss: 0.0720
# Epoch [11/15], Batch [300/782], Loss: 0.0748
# Epoch [11/15], Batch [400/782], Loss: 0.0861
# Epoch [11/15], Batch [500/782], Loss: 0.1047
# Epoch [11/15], Batch [600/782], Loss: 0.1071
# Epoch [11/15], Batch [700/782], Loss: 0.1153
# Epoch [12/15], Batch [100/782], Loss: 0.0678
# Epoch [12/15], Batch [200/782], Loss: 0.0544
# Epoch [12/15], Batch [300/782], Loss: 0.1236
# Epoch [12/15], Batch [400/782], Loss: 0.1194
# Epoch [12/15], Batch [500/782], Loss: 0.1023
# Epoch [12/15], Batch [600/782], Loss: 0.1092
# Epoch [12/15], Batch [700/782], Loss: 0.0998
# Epoch [13/15], Batch [100/782], Loss: 0.0678
# Epoch [13/15], Batch [200/782], Loss: 0.0541
# Epoch [13/15], Batch [300/782], Loss: 0.0713
# Epoch [13/15], Batch [400/782], Loss: 0.1026
# Epoch [13/15], Batch [500/782], Loss: 0.0795
# Epoch [13/15], Batch [600/782], Loss: 0.0964
# Epoch [13/15], Batch [700/782], Loss: 0.1131
# Epoch [14/15], Batch [100/782], Loss: 0.0533
# Epoch [14/15], Batch [200/782], Loss: 0.0526
# Epoch [14/15], Batch [300/782], Loss: 0.0632
# Epoch [14/15], Batch [400/782], Loss: 0.0706
# Epoch [14/15], Batch [500/782], Loss: 0.0927
# Epoch [14/15], Batch [600/782], Loss: 0.0865
# Epoch [14/15], Batch [700/782], Loss: 0.0917
# Epoch [15/15], Batch [100/782], Loss: 0.0613
# Epoch [15/15], Batch [200/782], Loss: 0.0687
# Epoch [15/15], Batch [300/782], Loss: 0.0879
# Epoch [15/15], Batch [400/782], Loss: 0.0616
# Epoch [15/15], Batch [500/782], Loss: 0.0909
# Epoch [15/15], Batch [600/782], Loss: 0.1017
# Epoch [15/15], Batch [700/782], Loss: 0.0679
# Student model testing without distillation:
# Accuracy: 76.34%
